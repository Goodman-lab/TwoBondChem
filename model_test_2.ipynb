# %%
from React import yr1_reactivity
from rdkit.Chem.Draw import SimilarityMaps

# %%
test = yr1_reactivity()
test.make_prediction('O=CC1=CC=CC=C1.[O-]C')
fig=SimilarityMaps.GetSimilarityMapFromWeights(test.mol_H_visual, test.pred, contourLines=10)

# %%
test = yr1_reactivity()
test.make_prediction('ClC(CC1=CC(COC)=CC=C1)=O.[C-]#N')
fig=SimilarityMaps.GetSimilarityMapFromWeights(test.mol_H_visual, test.pred, contourLines=10)

# %%
test = yr1_reactivity()
test.make_prediction('CC1(CC(C)(OC)C)OC1.C[N-]C')
fig=SimilarityMaps.GetSimilarityMapFromWeights(test.mol_H_visual, test.pred, contourLines=10)
