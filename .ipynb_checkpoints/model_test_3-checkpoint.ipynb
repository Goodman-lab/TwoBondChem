# %%
from React_v2 import reactivity
from rdkit.Chem.Draw import SimilarityMaps

# %%
test = reactivity(data='yr1')
test.make_prediction('C1C(Cl)OCCC1.N#[C-]')
fig=SimilarityMaps.GetSimilarityMapFromWeights(test.mol_H_visual, test.pred, contourLines=10)

# %%
test = reactivity(data='da')
test.make_prediction('[C:17]([C:18]#[N:19])([C:20]#[N:21])=[C:22]([C:23]#[N:24])[C:25]#[N:26].[C:1]([C:2]([O:3][P:4](=[O:5])([O:6][C:7]([C:8]([H:35])([H:36])[H:37])([H:33])[H:34])[O:9][C:10](/[C:11](=[C:12](/[Si:13]([C:14]([H:40])([H:41])[H:42])([C:15]([H:43])([H:44])[H:45])[C:16]([H:46])([H:47])[H:48])[H:39])[H:38])=[C:27]([H:49])[H:50])([H:31])[H:32])([H:28])([H:29])[H:30]')
fig=SimilarityMaps.GetSimilarityMapFromWeights(test.mol_H_visual, test.pred, contourLines=10)
# Out:
# /Users/chingchinglam/opt/anaconda3/lib/python3.8/site-packages/sklearn/base.py:324: UserWarning: Trying to unpickle estimator DecisionTreeClassifier from version 0.24.2 when using version 1.0.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/modules/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /Users/chingchinglam/opt/anaconda3/lib/python3.8/site-packages/sklearn/base.py:324: UserWarning: Trying to unpickle estimator RandomForestClassifier from version 0.24.2 when using version 1.0.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/modules/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
test = reactivity(data='cyclo')
test.make_prediction('[CH3:19][C:20]#[N+:21][NH-:22].[CH3:1][NH:2][C:3](=[O:4])[C:5]1([C:6]#[N:7])[C:8]#[C:9][C:10]([C:11]#[N:12])([C:13]#[N:14])[CH2:15][CH2:16][CH2:17][CH2:18]1')
fig=SimilarityMaps.GetSimilarityMapFromWeights(test.mol_H_visual, test.pred, contourLines=10)
# Out:
# /Users/chingchinglam/opt/anaconda3/lib/python3.8/site-packages/sklearn/base.py:324: UserWarning: Trying to unpickle estimator DecisionTreeClassifier from version 0.24.2 when using version 1.0.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/modules/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /Users/chingchinglam/opt/anaconda3/lib/python3.8/site-packages/sklearn/base.py:324: UserWarning: Trying to unpickle estimator RandomForestClassifier from version 0.24.2 when using version 1.0.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/modules/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
test = reactivity(data='green')
test.make_prediction('[C:1]1([H:7])([H:8])[C@@:2]2([H:9])[C@:3]1([H:10])[C@@:4]1([H:11])[N:5]([H:12])[C@@:6]21[H:13]')
fig=SimilarityMaps.GetSimilarityMapFromWeights(test.mol_H_visual, test.pred, contourLines=10)
# Out:
# /Users/chingchinglam/opt/anaconda3/lib/python3.8/site-packages/sklearn/base.py:324: UserWarning: Trying to unpickle estimator DecisionTreeClassifier from version 0.24.2 when using version 1.0.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/modules/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /Users/chingchinglam/opt/anaconda3/lib/python3.8/site-packages/sklearn/base.py:324: UserWarning: Trying to unpickle estimator RandomForestClassifier from version 0.24.2 when using version 1.0.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/modules/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
test = reactivity(data='rgd')
test.make_prediction('[C-:1]([C:4]([H:15])([H:16])[H:17])(/[N+:5](=[C:6](/[C:3]([H:12])([H:13])[H:14])[N:7]=[C:2]([H:10])[H:11])[H:8])[H:9]')
fig=SimilarityMaps.GetSimilarityMapFromWeights(test.mol_H_visual, test.pred, contourLines=10)

# %%
test = reactivity(data='Bmix')
test.make_prediction('[C:15]([S:16](=[O:17])(=[O:18])[C:19]1=[C:20]([H:29])[C:21]([H:30])=[C:22]([C:23]([H:31])([H:32])[H:33])[C:24]([H:34])=[C:25]1[H:35])#[C:26][H:36].[C:1]([C:2]([O:3][C:4](=[O:5])[C:6]1([N:7]([C:8]([C:9]([H:43])([H:44])[H:45])=[O:10])[H:42])[C:11]([H:46])([H:47])[C:12](=[C:27]([H:48])[H:49])[C:13](=[C:14]([H:50])[H:51])[C:28]1([H:52])[H:53])([H:40])[H:41])([H:37])([H:38])[H:39]')
fig=SimilarityMaps.GetSimilarityMapFromWeights(test.mol_H_visual, test.pred, contourLines=10)
# Out:
# /Users/chingchinglam/opt/anaconda3/lib/python3.8/site-packages/sklearn/base.py:324: UserWarning: Trying to unpickle estimator DecisionTreeClassifier from version 0.24.2 when using version 1.0.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/modules/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /Users/chingchinglam/opt/anaconda3/lib/python3.8/site-packages/sklearn/base.py:324: UserWarning: Trying to unpickle estimator RandomForestClassifier from version 0.24.2 when using version 1.0.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/modules/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
test = reactivity(data='Cmix')
test.make_prediction('[C-:1]([C:3]([H:12])([H:13])[H:14])(/[O+:6]=[N:5]\[H:8])[H:7].[C:2]([C:4]([H:15])([H:16])[H:17])([H:9])([H:10])[H:11]')
fig=SimilarityMaps.GetSimilarityMapFromWeights(test.mol_H_visual, test.pred, contourLines=10)
# Out:
# /Users/chingchinglam/opt/anaconda3/lib/python3.8/site-packages/sklearn/base.py:324: UserWarning: Trying to unpickle estimator DecisionTreeClassifier from version 0.24.2 when using version 1.0.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/modules/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /Users/chingchinglam/opt/anaconda3/lib/python3.8/site-packages/sklearn/base.py:324: UserWarning: Trying to unpickle estimator RandomForestClassifier from version 0.24.2 when using version 1.0.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/modules/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
test = reactivity(data='all')
test.make_prediction('[CH3:14][N-:15][NH+:16]=[N:17][C:18](=[O:19])[O:20][CH3:21].[CH3:1][O:2][C:3](=[O:4])[C:5]1=[C:6]([C:7]#[N:8])[CH:9]2[CH2:10][CH2:11][CH:12]1[CH2:13]2')
fig=SimilarityMaps.GetSimilarityMapFromWeights(test.mol_H_visual, test.pred, contourLines=10)
